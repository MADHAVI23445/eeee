# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('netflix.csv')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe().transpose()
# Out:
#                count         mean       std     min     25%     50%     75%  \
# release_year  8807.0  2014.180198  8.819312  1925.0  2013.0  2017.0  2019.0
#
#                  max
# release_year  2021.0

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
type(df['release_year'])
# Out:
# pandas.core.series.Series

# %%
mycols=['show_id','type']
df[mycols]
# Out:
#      show_id     type
# 0         s1    Movie
# 1         s2  TV Show
# 2         s3  TV Show
# 3         s4  TV Show
# 4         s5  TV Show
# ...      ...      ...
# 8802   s8803    Movie
# 8803   s8804  TV Show
# 8804   s8805    Movie
# 8805   s8806    Movie
# 8806   s8807    Movie
#
# [8807 rows x 2 columns]

# %%
df[['show_id','type']]
# Out:
#      show_id     type
# 0         s1    Movie
# 1         s2  TV Show
# 2         s3  TV Show
# 3         s4  TV Show
# 4         s5  TV Show
# ...      ...      ...
# 8802   s8803    Movie
# 8803   s8804  TV Show
# 8804   s8805    Movie
# 8805   s8806    Movie
# 8806   s8807    Movie
#
# [8807 rows x 2 columns]

# %%
df.drop('listed_in',axis=1)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df = pd.read_csv('netflix.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df= df.set_index('show_id')

# %%
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.reset_index().head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.iloc[0]
# Out:
# type                                                        Movie
# title                                        Dick Johnson Is Dead
# director                                          Kirsten Johnson
# cast                                                          NaN
# country                                             United States
# date_added                                     September 25, 2021
# release_year                                                 2020
# rating                                                      PG-13
# duration                                                   90 min
# listed_in                                           Documentaries
# description     As her father nears the end of his life, filmm...
# Name: s1, dtype: object

# %%
df.loc['s1']
# Out:
# type                                                        Movie
# title                                        Dick Johnson Is Dead
# director                                          Kirsten Johnson
# cast                                                          NaN
# country                                             United States
# date_added                                     September 25, 2021
# release_year                                                 2020
# rating                                                      PG-13
# duration                                                   90 min
# listed_in                                           Documentaries
# description     As her father nears the end of his life, filmm...
# Name: s1, dtype: object

# %%
df.iloc[0:4]
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df.loc[['s2','s4']]
# Out:
#             type                  title director  \
# show_id
# s2       TV Show          Blood & Water      NaN
# s4       TV Show  Jailbirds New Orleans      NaN
#
#                                                       cast       country  \
# show_id
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# s4                                                     NaN           NaN
#
#                  date_added  release_year rating   duration  \
# show_id
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s4       September 24, 2021          2021  TV-MA   1 Season
#
#                                                listed_in  \
# show_id
# s2       International TV Shows, TV Dramas, TV Mysteries
# s4                                Docuseries, Reality TV
#
#                                                description
# show_id
# s2       After crossing paths at a party, a Cape Town t...
# s4       Feuds, flirtations and toilet talk go down amo...

# %%
df.drop('s3').head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# s6       TV Show          Midnight Mass    Mike Flanagan
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
one= df.iloc[5]
one
# Out:
# type                                                      TV Show
# title                                               Midnight Mass
# director                                            Mike Flanagan
# cast            Kate Siegel, Zach Gilford, Hamish Linklater, H...
# country                                                       NaN
# date_added                                     September 24, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                 1 Season
# listed_in                      TV Dramas, TV Horror, TV Mysteries
# description     The arrival of a charismatic young priest brin...
# Name: s6, dtype: object

# %%
df= df.append(one)
df.tail()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5612\3029475661.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append(one)
#             type          title       director  \
# show_id
# s8806      Movie           Zoom   Peter Hewitt
# s8807      Movie         Zubaan    Mozez Singh
# s6       TV Show  Midnight Mass  Mike Flanagan
# s6       TV Show  Midnight Mass  Mike Flanagan
# s6       TV Show  Midnight Mass  Mike Flanagan
#
#                                                       cast        country  \
# show_id
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN
# ...

# %%
bool=df['release_year']>2015
df[bool]
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8798    TV Show              Zak Storm              NaN
# s8804    TV Show            Zombie Dumb              NaN
# s6       TV Show          Midnight Mass    Mike Flanagan
# s6       TV Show          Midnight Mass    Mike Flanagan
# s6       TV Show          Midnight Mass    Mike Flanagan
#
#                                                       cast  \
# show_id
# s1                                                     NaN
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df[df['release_year']>2015]
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8798    TV Show              Zak Storm              NaN
# s8804    TV Show            Zombie Dumb              NaN
# s6       TV Show          Midnight Mass    Mike Flanagan
# s6       TV Show          Midnight Mass    Mike Flanagan
# s6       TV Show          Midnight Mass    Mike Flanagan
#
#                                                       cast  \
# show_id
# s1                                                     NaN
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df = pd.read_csv('netflix.csv')

# %%
df[df['release_year']>2015]
# Out:
#      show_id     type                      title         director  \
# 0         s1    Movie       Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# ...      ...      ...                        ...              ...
# 8787   s8788    Movie  You Can’t Fight Christmas      Kenny Young
# 8794   s8795    Movie                     اشتباك     Mohamed Diab
# 8796   s8797  TV Show                 Yunus Emre              NaN
# 8797   s8798  TV Show                  Zak Storm              NaN
# 8803   s8804  TV Show                Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
df[df['type']=='Movie']
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df[(df['country'] == 'United States') &  (df['type']== 'Movie' )]
# Out:
#      show_id   type                 title          director  \
# 0         s1  Movie  Dick Johnson Is Dead   Kirsten Johnson
# 9        s10  Movie          The Starling    Theodore Melfi
# 27       s28  Movie             Grown Ups      Dennis Dugan
# 28       s29  Movie            Dark Skies     Scott Stewart
# 41       s42  Movie                  Jaws  Steven Spielberg
# ...      ...    ...                   ...               ...
# 8791   s8792  Movie           Young Adult     Jason Reitman
# 8793   s8794  Movie  Yours, Mine and Ours      Raja Gosnell
# 8802   s8803  Movie                Zodiac     David Fincher
# 8804   s8805  Movie            Zombieland   Ruben Fleischer
# 8805   s8806  Movie                  Zoom      Peter Hewitt
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %%
df[(df['country'] == 'United States') |  (df['type']== 'Movie' )]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df['type'].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
count1= ['India','United States']
df['country'].isin(count1)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 8802     True
# 8803    False
# 8804     True
# 8805     True
# 8806     True
# Name: country, Length: 8807, dtype: bool

# %%
df[df['country'].isin(count1)]
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 4         s5  TV Show          Kota Factory              NaN
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People              NaN
# 24       s25    Movie                 Jeans       S. Shankar
# ...      ...      ...                   ...              ...
# 8799   s8800    Movie                 Zenda   Avadhoot Gupte
# 8802   s8803    Movie                Zodiac    David Fincher
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
# 8806   s8807    Movie                Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...

# %%
np.round(df['release_year'].mean())
# Out:
# 2014.0

# %%
def yelp(year):
    if year== 2016:
        return '$'
    elif year>2015 and year<2020:
        return '$$'
    else:
        return '$$$'

# %%
df['release_year'].apply(yelp)
# Out:
# 0       $$$
# 1       $$$
# 2       $$$
# 3       $$$
# 4       $$$
#        ...
# 8802    $$$
# 8803     $$
# 8804    $$$
# 8805    $$$
# 8806    $$$
# Name: release_year, Length: 8807, dtype: object

# %%
df['time'] = df['release_year']/100
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
def quality(release_year,time):
    if release_year/time > 10:
        return 'geneerous'
    else:
        return "othrr"

# %%
df['quality']= df[['release_year','time']].apply(lambda df: quality(df['release_year'],df['time']),axis=1)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['quality'] = np.vectorize(quality)(df['release_year'],df['time'])
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.sort_values('time')
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          director  \
# 4250                          NaN
# 7790                  Frank Capra
# ...

# %%
df.sort_values('time',ascending = False)
# Out:
#      show_id     type                                          title  \
# 693     s694    Movie                         Ali & Ratu Ratu Queens
# 781     s782    Movie          Black Holes | The Edge of All We Know
# 762     s763    Movie                                   Sweet & Sour
# 763     s764  TV Show                                    Sweet Tooth
# 764     s765    Movie                   Trippin' with the Kandasamys
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             director                                               cast  \
# ...

# %%
df.sort_values(['release_year','time'])
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 1468   s1469    Movie                      What Happened to Mr. Cha?
# 1551   s1552  TV Show                                          Hilda
# 1696   s1697  TV Show                                   Polly Pocket
# 2920   s2921  TV Show                                  Love Is Blind
# 8437   s8438  TV Show                         The Netflix Afterparty
#
#                          director  \
# 4250                          NaN
# 7790                  Frank Capra
# ...

# %%
df['time'].max()
# Out:
# 20.21

# %%
df['release_year'].min()
# Out:
# 1925

# %%
df['release_year'].idxmin()
# Out:
# 4250

# %%
df.corr()
# Out:
#               release_year  time
# release_year           1.0   1.0
# time                   1.0   1.0

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df['release_year'].between(2000,2020,inclusive= True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5612\3150753458.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df['release_year'].between(2000,2020,inclusive= True)
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802     True
# 8803     True
# 8804     True
# 8805     True
# 8806     True
# Name: release_year, Length: 8807, dtype: bool

# %%
df[df['release_year'].between(2000,2020,inclusive=True)]
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5612\2708234757.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df[df['release_year'].between(2000,2020,inclusive=True)]
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 16       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17       s18  TV Show                                    Falsa identidad
# 21       s22  TV Show                             Resurrection: Ertugrul
# 27       s28    Movie                                          Grown Ups
# ...      ...      ...                                                ...
# 8802   s8803    Movie                                             Zodiac
# 8803   s8804  TV Show                                        Zombie Dumb
# 8804   s8805    Movie                                         Zombieland
# ...

# %%
df.nlargest(20,'time')
# Out:
#    show_id     type                                            title  \
# 1       s2  TV Show                                    Blood & Water
# 2       s3  TV Show                                        Ganglands
# 3       s4  TV Show                            Jailbirds New Orleans
# 4       s5  TV Show                                     Kota Factory
# 5       s6  TV Show                                    Midnight Mass
# 6       s7    Movie                 My Little Pony: A New Generation
# 8       s9  TV Show                    The Great British Baking Show
# 9      s10    Movie                                     The Starling
# 10     s11  TV Show              Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                 Bangkok Breaking
# 12     s13    Movie                                     Je Suis Karl
# 13     s14    Movie                 Confessions of an Invisible Girl
# 14     s15  TV Show                  Crime Stories: India Detectives
# ...

# %%
df.sample(frac=0.1)
# Out:
#      show_id     type                                       title  \
# 8262   s8263  TV Show                     The Curse of Oak Island
# 6166   s6167  TV Show                         Anjaan: Rural Myths
# 4683   s4684    Movie  Maria Bamford: The Special Special Special
# 3336   s3337  TV Show                                    Haikyu!!
# 6258   s6259  TV Show                                 Be-Be-Bears
# ...      ...      ...                                         ...
# 1958   s1959  TV Show                               The Chef Show
# 5396   s5397    Movie                                 Lal Patthar
# 2452   s2453  TV Show                                 My Shy Boss
# 763     s764  TV Show                                 Sweet Tooth
# 6654   s6655    Movie                                         Dum
#
#              director                                               cast  \
# 8262              NaN                                  Robert Clotworthy
# ...

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description   time  quality
# 0            False   False     False      False        False  False    False
# ...

# %%
df.notnull()
# Out:
#       show_id  type  title  director   cast  country  date_added  \
# 0        True  True   True      True  False     True        True
# 1        True  True   True     False   True     True        True
# 2        True  True   True      True   True    False        True
# 3        True  True   True     False  False    False        True
# 4        True  True   True     False   True     True        True
# ...       ...   ...    ...       ...    ...      ...         ...
# 8802     True  True   True      True   True     True        True
# 8803     True  True   True     False  False    False        True
# 8804     True  True   True      True   True     True        True
# 8805     True  True   True      True   True     True        True
# 8806     True  True   True      True   True     True        True
#
#       release_year  rating  duration  listed_in  description  time  quality
# 0             True    True      True       True         True  True     True
# ...

# %%
df['cast'].isnull()
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8802    False
# 8803     True
# 8804    False
# 8805    False
# 8806    False
# Name: cast, Length: 8807, dtype: bool

# %%
df['cast'].notnull()
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 8802     True
# 8803    False
# 8804     True
# 8805     True
# 8806     True
# Name: cast, Length: 8807, dtype: bool

# %%
df[df['cast'].notnull()]
# Out:
#      show_id     type                             title  \
# 1         s2  TV Show                     Blood & Water
# 2         s3  TV Show                         Ganglands
# 4         s5  TV Show                      Kota Factory
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 1                               NaN
# 2                   Julien Leclercq
# 4                               NaN
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# ...                             ...
# ...

# %%
df[df['cast'].isnull()]
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 3         s4  TV Show                              Jailbirds New Orleans
# 10       s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 14       s15  TV Show                    Crime Stories: India Detectives
# 16       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# ...      ...      ...                                                ...
# 8746   s8747    Movie                                             Winnie
# 8755   s8756  TV Show                                  Women Behind Bars
# 8756   s8757    Movie                                          Woodstock
# 8763   s8764    Movie                    WWII: Report from the Aleutians
# 8803   s8804  TV Show                                        Zombie Dumb
#
#                                            director cast  \
# ...

# %%
df[df['cast'].isnull() & df['director'].notnull()]
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 16       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 20       s21  TV Show    Monsters Inside: The 24 Faces of Billy Milligan
# 45       s46    Movie                             My Heroes Were Cowboys
# 91       s92    Movie                         The Women and the Murderer
# ...      ...      ...                                                ...
# 8739   s8740    Movie                 Why We Fight: The Battle of Russia
# 8744   s8745    Movie                                           Williams
# 8746   s8747    Movie                                             Winnie
# 8756   s8757    Movie                                          Woodstock
# 8763   s8764    Movie                    WWII: Report from the Aleutians
#
#                                            director cast  \
# ...

# %%
df.dropna()
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df.dropna(axis=1)
# Out:
#      show_id     type                  title  release_year  \
# 0         s1    Movie   Dick Johnson Is Dead          2020
# 1         s2  TV Show          Blood & Water          2021
# 2         s3  TV Show              Ganglands          2021
# 3         s4  TV Show  Jailbirds New Orleans          2021
# 4         s5  TV Show           Kota Factory          2021
# ...      ...      ...                    ...           ...
# 8802   s8803    Movie                 Zodiac          2007
# 8803   s8804  TV Show            Zombie Dumb          2018
# 8804   s8805    Movie             Zombieland          2009
# 8805   s8806    Movie                   Zoom          2006
# 8806   s8807    Movie                 Zubaan          2015
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.dropna(axis=0)
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df.dropna(subset=['cast'])
# Out:
#      show_id     type                             title  \
# 1         s2  TV Show                     Blood & Water
# 2         s3  TV Show                         Ganglands
# 4         s5  TV Show                      Kota Factory
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 1                               NaN
# 2                   Julien Leclercq
# 4                               NaN
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# ...                             ...
# ...

# %%
df.fillna('new')
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              new
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              new
# 4         s5  TV Show           Kota Factory              new
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              new
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   new  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['director']= df['director'].fillna('madhu')
df['director']
# Out:
# 0       Kirsten Johnson
# 1                 madhu
# 2       Julien Leclercq
# 3                 madhu
# 4                 madhu
#              ...
# 8802      David Fincher
# 8803              madhu
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
df['release_year'].value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
df.groupby('release_year')

# %%
df.groupby('release_year').mean()
# Out:
#                time
# release_year
# 1925          19.25
# 1942          19.42
# 1943          19.43
# 1944          19.44
# 1945          19.45
# ...             ...
# 2017          20.17
# 2018          20.18
# 2019          20.19
# 2020          20.20
# 2021          20.21
#
# [74 rows x 1 columns]

# %%
df.groupby(['release_year','country']).mean().head(30)
# Out:
#                                                                   time
# release_year country
# 1942         United States                                       19.42
# 1943         United States                                       19.43
# 1944         United States                                       19.44
#              United States, United Kingdom                       19.44
# 1945         United States                                       19.45
# 1946         United States                                       19.46
# 1947         United States                                       19.47
# 1954         Egypt                                               19.54
#              United States                                       19.54
# 1955         Italy                                               19.55
#              Italy, France                                       19.55
#              United States                                       19.55
# ...

# %%
df.groupby(['country','release_year']).mean().head(30)
# Out:
#                                                                   time
# country                                            release_year
# , France, Algeria                                  2014          20.14
# , South Korea                                      2021          20.21
# Argentina                                          1985          19.85
#                                                    1998          19.98
#                                                    2004          20.04
#                                                    2006          20.06
#                                                    2007          20.07
#                                                    2015          20.15
#                                                    2016          20.16
#                                                    2017          20.17
#                                                    2018          20.18
# ...

# %%
df.groupby(['country','release_year']).mean().columns
# Out:
# Index(['time'], dtype='object')

# %%
df.groupby(['release_year','country']).mean().index
# Out:
# MultiIndex([(1942,                              'United States'),
#             (1943,                              'United States'),
#             (1944,                              'United States'),
#             (1944,              'United States, United Kingdom'),
#             (1945,                              'United States'),
#             (1946,                              'United States'),
#             (1947,                              'United States'),
#             (1954,                                      'Egypt'),
#             (1954,                              'United States'),
#             (1955,                                      'Italy'),
#             ...
#             (2021, 'United States, Brazil, Japan, Spain, India'),
#             (2021,                      'United States, Canada'),
#             (2021,              'United States, Czech Republic'),
#             (2021,                       'United States, India'),
# ...

# %%
xxx=df.groupby(['release_year','country']).mean()['time']

# %%
xxx.xs(key='Vietnam',level='country')
# Out:
# release_year
# 2014    20.14
# 2015    20.15
# 2016    20.16
# 2019    20.19
# 2020    20.20
# 2021    20.21
# Name: time, dtype: float64

# %%
xxx.xs(key=2021,level='release_year')
# Out:
# country
# , South Korea                    20.21
# Argentina                        20.21
# Australia                        20.21
# Australia, United Kingdom        20.21
# Australia, United States         20.21
#                                  ...
# United States, Mexico            20.21
# United States, Singapore         20.21
# United States, United Kingdom    20.21
# Uruguay, Germany                 20.21
# Vietnam                          20.21
# Name: time, Length: 75, dtype: float64

# %%
xxx.sort_index(level='release_year')
# Out:
# release_year  country
# 1942          United States                    19.42
# 1943          United States                    19.43
# 1944          United States                    19.44
#               United States, United Kingdom    19.44
# 1945          United States                    19.45
#                                                ...
# 2021          United States, Mexico            20.21
#               United States, Singapore         20.21
#               United States, United Kingdom    20.21
#               Uruguay, Germany                 20.21
#               Vietnam                          20.21
# Name: time, Length: 1754, dtype: float64

# %%
df.agg(['std','mean'])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5612\3322197462.py:1: FutureWarning: ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'rating', 'duration', 'listed_in', 'description', 'quality'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.agg(['std','mean'])
#       release_year       time
# std       8.819312   0.088193
# mean   2014.180198  20.141802

# %%
df.agg({'release_year':['max','mean'],'time':['max','mean']})
# Out:
#       release_year       time
# max    2021.000000  20.210000
# mean   2014.180198  20.141802

# %%
df.groupby('country').describe()
# Out:
#                                                    release_year               \
#                                                           count         mean
# country
# , France, Algeria                                           1.0  2014.000000
# , South Korea                                               1.0  2021.000000
# Argentina                                                  56.0  2016.000000
# Argentina, Brazil, France, Poland, Germany, Den...          1.0  2017.000000
# Argentina, Chile                                            2.0  2011.500000
# ...                                                         ...          ...
# Venezuela                                                   1.0  2017.000000
# Venezuela, Colombia                                         1.0  2007.000000
# Vietnam                                                     7.0  2017.714286
# West Germany                                                1.0  1977.000000
# ...

# %%
df.groupby('country').describe().transpose()
# Out:
# country             , France, Algeria  , South Korea    Argentina  \
# release_year count               1.00           1.00    56.000000
#              mean             2014.00        2021.00  2016.000000
#              std                  NaN            NaN     7.336088
#              min              2014.00        2021.00  1985.000000
#              25%              2014.00        2021.00  2016.000000
#              50%              2014.00        2021.00  2018.000000
#              75%              2014.00        2021.00  2019.250000
#              max              2014.00        2021.00  2021.000000
# time         count               1.00           1.00    56.000000
#              mean               20.14          20.21    20.160000
#              std                  NaN            NaN     0.073361
#              min                20.14          20.21    19.850000
#              25%                20.14          20.21    20.160000
# ...

# %%
df.groupby('release_year').describe()
# Out:
#                 time
#                count   mean           std    min    25%    50%    75%    max
# release_year
# 1925             1.0  19.25           NaN  19.25  19.25  19.25  19.25  19.25
# 1942             2.0  19.42  0.000000e+00  19.42  19.42  19.42  19.42  19.42
# 1943             3.0  19.43  0.000000e+00  19.43  19.43  19.43  19.43  19.43
# 1944             3.0  19.44  0.000000e+00  19.44  19.44  19.44  19.44  19.44
# 1945             4.0  19.45  0.000000e+00  19.45  19.45  19.45  19.45  19.45
# ...              ...    ...           ...    ...    ...    ...    ...    ...
# 2017          1032.0  20.17  3.198993e-13  20.17  20.17  20.17  20.17  20.17
# 2018          1147.0  20.18  2.239186e-13  20.18  20.18  20.18  20.18  20.18
# 2019          1030.0  20.19  1.492865e-13  20.19  20.19  20.19  20.19  20.19
# 2020           953.0  20.20  3.625671e-13  20.20  20.20  20.20  20.20  20.20
# 2021           592.0  20.21  2.524560e-13  20.21  20.21  20.21  20.21  20.21
#
# ...

# %%
mistr = df.groupby(['release_year','time']).mean()
mistr
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5612\4019946174.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   mistr = df.groupby(['release_year','time']).mean()
# Empty DataFrame
# Columns: []
# ...

# %%
mistr.index.levels
# Out:
# FrozenList([[1925, 1942, 1943, 1944, 1945, 1946, 1947, 1954, 1955, 1956, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021], [19.25, 19.42, 19.43, 19.44, 19.45, 19.46, 19.47, 19.54, 19.55, 19.56, 19.58, 19.59, 19.6, 19.61, 19.62, 19.63, 19.64, 19.65, 19.66, 19.67, 19.68, 19.69, 19.7, 19.71, 19.72, 19.73, 19.74, 19.75, 19.76, 19.77, 19.78, 19.79, 19.8, 19.81, 19.82, 19.83, 19.84, 19.85, 19.86, 19.87, 19.88, 19.89, 19.9, 19.91, 19.92, 19.93, 19.94, 19.95, 19.96, 19.97, 19.98, 19.99, 20.0, 20.01, 20.02, 20.03, 20.04, 20.05, 20.06, 20.07, 20.08, 20.09, 20.1, 20.11, 20.12, 20.13, 20.14, 20.15, 20.16, 20.17, 20.18, 20.19, 20.2, 20.21]])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('netflix.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
sns.scatterplot(x=df['type'],y=df['rating'],data=df)
plt.title('Type vs rating');

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df['type'],y=df['rating'],data=df,s=100)
plt.title('Type vs rating');

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df['type'],y=df['rating'],data=df,s=100,style= 'type')
plt.title('Type vs rating');

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df['type'],y=df['rating'],data=df,s=100,style= 'type')
plt.title('Type vs rating',fontsize= 22);

# %%
sns.rugplot(x='release_year',data=df)
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
sns.rugplot(x='release_year',data=df,height=0.5)
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
sns.displot(data=df,x='release_year',bins=50,linewidth=4)

# %%
sns.displot(data=df,x='release_year',bins=50,linewidth=4,edgecolor='yellow',ls="--")

# %%
sns.displot(x='release_year',data=df,kde= True)

# %%
sns.kdeplot(data=df,x='release_year')
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='release_year',bw_adjust=4)
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='release_year',bw_adjust=4,color= 'red',shade=True)
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='Density'>
